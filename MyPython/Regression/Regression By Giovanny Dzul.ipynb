# %% [markdown]
# ## Regression simple

# %%
#Import the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#Get and print the table
url = "https://raw.githubusercontent.com/giodp2408/bigdata2020UTM/master/califi.csv"
score = pd.read_csv(url)
print("Table: The highest school score every year")
print()
print(score.head(10))
print()
print(score.tail(10))
# Out:
# Table: The highest school score every year
#
#    Year  Men  Women
# 0  1968   80     81
# 1  1969   99     94
# 2  1970   90     76
# 3  1971   75     89
# 4  1972   94     70
# 5  1973   72     75
# 6  1974   97     72
# 7  1975   84     91
# 8  1976   86     98
# 9  1977   88     73
#
#     Year  Men  Women
# 43  2011   84     99
# 44  2012   91     94
# 45  2013   94     72
# 46  2014   84     91
# 47  2015   86     79
# 48  2016   95     94
# 49  2017   93     90
# 50  2018   74     89
# 51  2019   83     78
# 52  2020   78     71

# %%
#Get the X and Y axis
x = score.iloc[:, 0].values
x =x.reshape(-1,1)
y = score.iloc[:, 2].values
y =y.reshape(-1,1)

#Get the prediction and accuracy
X_train, X_test, y_train ,y_test = train_test_split(x, y, test_size=0.2)
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
Y_pred = lr.predict(X_test)

#Print the results
plt.scatter(x, y, color = 'blue')
plt.plot(X_test, Y_pred, color='red', linewidth=3)
plt.title("The highest school score every year (Only women)")
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()
print("The accuracy of the model is:", lr.score(X_train, y_train))
# Out:
# The accuracy of the model is: 0.005370542107772546

# %%
#Get the X and Y axis
x = score.iloc[:, 0].values
x =x.reshape(-1,1)
y = score.iloc[:, 1].values
y =y.reshape(-1,1)

#Get the prediction and accuracy
X_train, X_test, y_train ,y_test = train_test_split(x, y, test_size=0.2)
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
Y_pred = lr.predict(X_test)

#Print the results
plt.scatter(x, y, color = 'blue')
plt.plot(X_test, Y_pred, color='red', linewidth=3)
plt.title("The highest school score every year (Only men)")
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()
print("The accuracy of the model is:", lr.score(X_train, y_train))
# Out:
# The accuracy of the model is: 0.003972671191060373
